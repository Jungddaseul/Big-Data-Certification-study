# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 64. 데이터를 로드하고 각 열의 데이터 타입을 파악하라

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/timeTest.csv')

df.head()
# Out:
#      Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Yr_Mo_Dy  6574 non-null   object
#  1   RPT       6568 non-null   float64
#  2   VAL       6571 non-null   float64
#  3   ROS       6572 non-null   float64
#  4   KIL       6569 non-null   float64
#  5   SHA       6572 non-null   float64
#  6   BIR       6574 non-null   float64
#  7   DUB       6571 non-null   float64
#  8   CLA       6572 non-null   float64
#  9   MUL       6571 non-null   float64
#  10  CLO       6573 non-null   float64
#  11  BEL       6574 non-null   float64
#  12  MAL       6570 non-null   float64
# dtypes: float64(12), object(1)
# memory usage: 667.8+ KB

# %% [markdown]
# ### 65. Yr_Mo_Dy을 판다스에서 인식할 수 있는 datetime64타입으로 변경하라

# %%
df['Yr_Mo_Dy'] = pd.to_datetime(df['Yr_Mo_Dy'])
Ans = df['Yr_Mo_Dy']
Ans
# Out:
# 0      2061-01-01
# 1      2061-01-02
# 2      2061-01-03
# 3      2061-01-04
# 4      2061-01-05
#           ...
# 6569   1978-12-27
# 6570   1978-12-28
# 6571   1978-12-29
# 6572   1978-12-30
# 6573   1978-12-31
# Name: Yr_Mo_Dy, Length: 6574, dtype: datetime64[ns]

# %% [markdown]
# ### ✅ 66. Yr_Mo_Dy에 존재하는 년도의 유일값을 모두 출력하라

# %%
Ans = df['Yr_Mo_Dy'].dt.year.unique()
Ans
# Out:
# array([2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978], dtype=int64)

# %% [markdown]
# ### ✅ 67. Yr_Mo_Dy에 년도가 2061년 이상의 경우에는 모두 잘못된 데이터이다. 해당경우의 값은 100을 빼서 새롭게 날짜를 Yr_Mo_Dy 컬럼에 정의하라

# %%
def fix_century(x):
    import datetime
    
    year = x.year - 100 if x.year >= 2061 else x.year
    return pd.to_datetime(datetime.date(year, x.month, x.day))

df['Yr_Mo_Dy'] = df['Yr_Mo_Dy'].apply(fix_century)

df.head()
# Out:
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# ### 68. 년도별 각컬럼의 평균값을 구하여라

# %%
Ans = df.groupby(df['Yr_Mo_Dy'].dt.year).mean()
Ans.head()
# Out:
# C:\Users\161332\AppData\Local\Temp\ipykernel_1620\2886690531.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Ans = df.groupby(df['Yr_Mo_Dy'].dt.year).mean()
#                 RPT        VAL        ROS       KIL        SHA       BIR  \
# Yr_Mo_Dy
# 1961      12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962      12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963      12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964      12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965      12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
#
#                 DUB        CLA       MUL        CLO        BEL        MAL
# Yr_Mo_Dy
# 1961       9.733923   8.858788  8.647652   9.835577  13.502795  13.680773
# 1962      11.020712   8.793753  8.316822   9.676247  12.930685  14.323956
# 1963      11.075699  10.336548  8.903589  10.224438  13.638877  14.999014
# 1964      10.259153   9.467350  7.789016  10.207951  13.740546  14.910301
# 1965      10.618712   8.879918  7.907425   9.918082  12.964247  15.591644

# %% [markdown]
# ### 69. weekday컬럼을 만들고 요일별로 매핑하라 ( 월요일: 0 ~ 일요일 :6)

# %%
df['weekday'] = df['Yr_Mo_Dy'].dt.weekday
Ans = df['weekday'].to_frame()
Ans.head()
# Out:
#    weekday
# 0        6
# 1        0
# 2        1
# 3        2
# 4        3

# %% [markdown]
# ### 70. weekday컬럼을 기준으로 주말이면 1 평일이면 0의 값을 가지는 WeekCheck 컬럼을 만들어라

# %%
df['weekday'].unique()
# Out:
# array([6, 0, 1, 2, 3, 4, 5], dtype=int64)

# %%
df['WeekCheck'] = df['weekday'].map(lambda x : 1 if x in [5, 6] else 0 )
Ans = df['WeekCheck'].to_frame()
Ans.head()
# Out:
#    WeekCheck
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# ### 71.년도, 일자 상관없이 모든 컬럼의 각 달의 평균을 구하여라

# %%
df.head(3)
# Out:
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
#
#      CLO    BEL    MAL  weekday  WeekCheck
# 0  12.58  18.50  15.04        6          1
# 1   9.67  17.54  13.83        0          0
# 2   7.67  12.75  12.71        1          0

# %%
Ans = df.groupby(df['Yr_Mo_Dy'].dt.month).mean()
Ans.head()
# Out:
# C:\Users\161332\AppData\Local\Temp\ipykernel_1620\705423745.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Ans = df.groupby(df['Yr_Mo_Dy'].dt.month).mean()
#                 RPT        VAL        ROS       KIL        SHA       BIR  \
# Yr_Mo_Dy
# 1         14.847325  12.914560  13.299624  7.199498  11.667734  8.054839
# 2         13.710906  12.111122  12.879132  6.942411  11.551772  7.633858
# 3         13.158687  11.505842  12.648118  7.265907  11.554516  7.959409
# 4         12.555648  10.429759  12.204815  6.898037  10.677667  7.441389
# 5         11.724032  10.145619  11.550394  6.307487  10.224301  6.942061
#
#                 DUB       CLA       MUL        CLO        BEL        MAL  \
# Yr_Mo_Dy
# 1         11.819355  9.512047  9.543208  10.053566  14.550520  18.028763
# 2         11.206024  9.341437  9.313169   9.518051  13.728898  17.156142
# 3         11.310179  9.635896  9.700324  10.096953  13.810609  16.909317
# 4         10.221315  8.909056  8.930870   9.158019  12.664759  14.937611
# 5          8.797738  8.452903  8.040806   8.524857  12.767258  13.736039
#
#            weekday  WeekCheck
# Yr_Mo_Dy
# 1         2.989247   0.284946
# 2         3.005906   0.287402
# 3         3.000000   0.283154
# 4         3.011111   0.288889
# 5         2.982079   0.283154

# %% [markdown]
# ### ✅ 72.모든 결측치는 컬럼기준 직전의 값으로 대체하고 첫번째 행에 결측치가 있을경우 뒤에있는 값으로 대채하라

# %%
df.isnull().sum()
# Out:
# Yr_Mo_Dy     0
# RPT          6
# VAL          3
# ROS          2
# KIL          5
# SHA          2
# BIR          0
# DUB          3
# CLA          2
# MUL          3
# CLO          1
# BEL          0
# MAL          4
# weekday      0
# WeekCheck    0
# dtype: int64

# %%
df = df.fillna(method='ffill').fillna(method='bfill')

# %%
df.isnull().sum()
# Out:
# Yr_Mo_Dy     0
# RPT          0
# VAL          0
# ROS          0
# KIL          0
# SHA          0
# BIR          0
# DUB          0
# CLA          0
# MUL          0
# CLO          0
# BEL          0
# MAL          0
# weekday      0
# WeekCheck    0
# dtype: int64

# %% [markdown]
# ### ✅ 73. 년도 - 월을 기준으로 모든 컬럼의 평균값을 구하여라

# %%
Ans = df.groupby(df['Yr_Mo_Dy'].dt.to_period('M')).mean()
Ans.head()
# Out:
# C:\Users\161332\AppData\Local\Temp\ipykernel_1620\2287556515.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Ans = df.groupby(df['Yr_Mo_Dy'].dt.to_period('M')).mean()
#                 RPT        VAL        ROS       KIL        SHA        BIR  \
# Yr_Mo_Dy
# 1961-01   14.932581  12.084194  13.431613  7.736774  11.215806   8.588065
# 1961-02   16.269286  14.975357  14.324643  9.116786  13.852143  10.937500
# 1961-03   11.015806  11.296452  10.752903  7.137742  10.509355   8.866774
# 1961-04   10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05    9.860968   8.735161  10.818065  5.892258   9.490323   6.574839
#
#                 DUB        CLA        MUL        CLO        BEL        MAL  \
# Yr_Mo_Dy
# 1961-01   11.184839   9.270968   9.085806  10.107419  13.880968  14.703226
# 1961-02   11.890714  11.846071  11.821429  12.714286  18.583214  15.411786
# 1961-03    9.644194   9.829677  10.646129  11.251935  16.410968  15.637742
# 1961-04    6.925333   7.094667   7.342333   7.237000  11.147333  10.278333
# 1961-05    7.477097   8.177097   8.039355   8.499355  11.900323  12.011613
#
#            weekday  WeekCheck
# Yr_Mo_Dy
# 1961-01   2.935484   0.290323
# 1961-02   3.000000   0.285714
# 1961-03   3.000000   0.258065
# 1961-04   3.166667   0.333333
# 1961-05   2.806452   0.258065

# %% [markdown]
# ### ✅ 74. RPT 컬럼의 값을 일자별 기준으로 1차차분하라

# %%
Ans = df['RPT'].diff()
Ans.head()
# Out:
# 0     NaN
# 1   -0.33
# 2    3.79
# 3   -7.92
# 4    2.75
# Name: RPT, dtype: float64

# %% [markdown]
# ### ✅ 75. RPT와 VAL의 컬럼을 일주일 간격으로 각각 이동평균한값을 구하여라

# %%
Ans = df[['RPT', 'VAL']].rolling(7).mean()
Ans.head(9)
# Out:
#          RPT        VAL
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# 5        NaN        NaN
# 6  14.124286  12.727143
# 7  13.541429  11.982857
# 8  13.237143  11.392857

# %% [markdown]
# ### ✅ 76. 년-월-일:시 컬럼을 pandas에서 인식할 수 있는 datetime 형태로 변경하라. 서울시의 제공데이터의 경우 0시가 24시로 표현된다

# %%
df =pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/seoul_pm.csv')

# %%
df.head()
# Out:
#        (년-월-일:시) PM10등급  PM10 PM2.5등급  PM2.5 오존등급     오존 이산화질소등급  이산화질소  \
# 0  2021-05-15:15     보통  47.0      보통   19.0   좋음  0.017      좋음  0.023
# 1  2021-05-15:14     보통  43.0      보통   20.0   좋음  0.024      좋음  0.019
# 2  2021-05-15:13     보통  34.0      보통   24.0   보통  0.035      좋음  0.017
# 3  2021-05-15:12     보통  41.0      보통   27.0   보통  0.037      좋음  0.020
# 4  2021-05-15:11     보통  51.0      보통   34.0   보통  0.033      좋음  0.023
#
#   일산화탄소등급  일산화탄소 아황산가스등급  아황산가스
# 0      좋음    0.4      좋음  0.003
# 1      좋음    0.3      좋음  0.003
# 2      좋음    0.4      좋음  0.004
# 3      좋음    0.4      좋음  0.004
# 4      좋음    0.4      좋음  0.005

# %%
df['(년-월-일:시)'][0]
# Out:
# '2021-05-15:15'

# %%
# df['(년-월-일:시)'] 걸 문자열로 바꿔서 시간부분만 추출

df['(년-월-일:시)'].str[-2:][0]
# Out:
# '15'

# %%
a = '2021-05-15:15'
a.split(':')
# Out:
# ['2021-05-15', '15']

# %%
pd.to_datetime(a.split(':')[0])
# Out:
# Timestamp('2021-05-15 00:00:00')

# %%
#  아래와 같이 :표시없이 띄어쓰기로 작성해야지 시간으로 인식함

pd.to_datetime('2021-05-15 13')
# Out:
# Timestamp('2021-05-15 13:00:00')

# %%
import datetime

pd.to_datetime('2022-04-30') + datetime.timedelta(days = 1)
# Out:
# Timestamp('2022-05-01 00:00:00')

# %%
def change_date(x):
    import datetime
    if x[-2:] != '24':
        x = x.replace(':', ' ') # 시간을 인식하기 위해 콜론을 띄어쓰기로 변경
        return pd.to_datetime(x)
    
    else:
        date = pd.to_datetime(x.split(':')[0]) + datetime.timedelta(days = 1)
        return date
    
df.loc[:, '(년-월-일:시)'] = df['(년-월-일:시)'].apply(change_date)
# Out:
# C:\Users\161332\AppData\Local\Temp\ipykernel_1620\1512210376.py:11: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, '(년-월-일:시)'] = df['(년-월-일:시)'].apply(change_date)

# %%
df.head()
# Out:
#             (년-월-일:시) PM10등급  PM10 PM2.5등급  PM2.5 오존등급     오존 이산화질소등급  이산화질소  \
# 0 2021-05-15 15:00:00     보통  47.0      보통   19.0   좋음  0.017      좋음  0.023
# 1 2021-05-15 14:00:00     보통  43.0      보통   20.0   좋음  0.024      좋음  0.019
# 2 2021-05-15 13:00:00     보통  34.0      보통   24.0   보통  0.035      좋음  0.017
# 3 2021-05-15 12:00:00     보통  41.0      보통   27.0   보통  0.037      좋음  0.020
# 4 2021-05-15 11:00:00     보통  51.0      보통   34.0   보통  0.033      좋음  0.023
#
#   일산화탄소등급  일산화탄소 아황산가스등급  아황산가스
# 0      좋음    0.4      좋음  0.003
# 1      좋음    0.3      좋음  0.003
# 2      좋음    0.4      좋음  0.004
# 3      좋음    0.4      좋음  0.004
# 4      좋음    0.4      좋음  0.005

# %% [markdown]
# ### 77. 일자별 영어요일 이름을 dayName 컬럼에 저장하라

# %%
dir(df['(년-월-일:시)'].dt)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__frozen',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_add_delegate_accessors',
#  '_constructor',
#  '_delegate_method',
#  '_delegate_property_get',
#  '_delegate_property_set',
#  '_dir_additions',
#  '_dir_deletions',
#  '_freeze',
#  '_get_values',
#  '_hidden_attrs',
#  '_parent',
#  '_reset_cache',
#  'ceil',
#  'date',
#  'day',
#  'day_name',
#  'day_of_week',
#  'day_of_year',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
#  'floor',
#  'freq',
#  'hour',
#  'is_leap_year',
#  'is_month_end',
#  'is_month_start',
#  'is_quarter_end',
#  'is_quarter_start',
#  'is_year_end',
#  'is_year_start',
#  'isocalendar',
#  'microsecond',
#  'minute',
#  'month',
#  'month_name',
#  'nanosecond',
#  'normalize',
#  'quarter',
#  'round',
#  'second',
#  'strftime',
#  'time',
#  'timetz',
#  'to_period',
#  'to_pydatetime',
#  'tz',
#  'tz_convert',
#  'tz_localize',
#  'week',
#  'weekday',
#  'weekofyear',
#  'year']

# %%
df.loc[:, 'dayName'] = df['(년-월-일:시)'].dt.day_name()
df['dayName'].head()
# Out:
# 0    Saturday
# 1    Saturday
# 2    Saturday
# 3    Saturday
# 4    Saturday
# Name: dayName, dtype: object

# %% [markdown]
# ### ✅ 78. 일자별 각 PM10등급의 빈도수를 파악하라

# %%
df.head()
# Out:
#             (년-월-일:시) PM10등급  PM10 PM2.5등급  PM2.5 오존등급     오존 이산화질소등급  이산화질소  \
# 0 2021-05-15 15:00:00     보통  47.0      보통   19.0   좋음  0.017      좋음  0.023
# 1 2021-05-15 14:00:00     보통  43.0      보통   20.0   좋음  0.024      좋음  0.019
# 2 2021-05-15 13:00:00     보통  34.0      보통   24.0   보통  0.035      좋음  0.017
# 3 2021-05-15 12:00:00     보통  41.0      보통   27.0   보통  0.037      좋음  0.020
# 4 2021-05-15 11:00:00     보통  51.0      보통   34.0   보통  0.033      좋음  0.023
#
#   일산화탄소등급  일산화탄소 아황산가스등급  아황산가스   dayName
# 0      좋음    0.4      좋음  0.003  Saturday
# 1      좋음    0.3      좋음  0.003  Saturday
# 2      좋음    0.4      좋음  0.004  Saturday
# 3      좋음    0.4      좋음  0.004  Saturday
# 4      좋음    0.4      좋음  0.005  Saturday

# %%
Ans1 = df.groupby(['dayName', 'PM10등급'], as_index=False).size()
Ans2 = Ans1.pivot(index='dayName', columns='PM10등급', values='size').fillna(0)

# %%
Ans1.head()
# Out:
#   dayName PM10등급  size
# 0  Friday     나쁨    31
# 1  Friday   매우나쁨    17
# 2  Friday     보통   120
# 3  Friday     좋음    21
# 4  Monday     나쁨     1

# %%
Ans2.head()
# Out:
# PM10등급      나쁨  매우나쁨     보통    좋음
# dayName
# Friday    31.0  17.0  120.0  21.0
# Monday     1.0  21.0   83.0  63.0
# Saturday  31.0  27.0   71.0  54.0
# Sunday     2.0   1.0   67.0  98.0
# Thursday  41.0   0.0  144.0   5.0

# %% [markdown]
# ### ✅  79. 시간이 연속적으로 존재하며 결측치가 없는지 확인하라

# %%
# 시간을 차분했을 경우 첫 값은 nan, 이후 모든 차분값이 동일하면 연속이라 판단한다.
check = len(df['(년-월-일:시)'].diff().dropna().unique())

if check == 1:
    Ans = True
else:
    Ans = False
    
Ans
# Out:
# True

# %% [markdown]
# ### ✅ 80. 오전 10시와 오후 10시(22시)의 PM10의 평균값을 각각 구하여라|

# %%
df.head()
# Out:
#             (년-월-일:시) PM10등급  PM10 PM2.5등급  PM2.5 오존등급     오존 이산화질소등급  이산화질소  \
# 0 2021-05-15 15:00:00     보통  47.0      보통   19.0   좋음  0.017      좋음  0.023
# 1 2021-05-15 14:00:00     보통  43.0      보통   20.0   좋음  0.024      좋음  0.019
# 2 2021-05-15 13:00:00     보통  34.0      보통   24.0   보통  0.035      좋음  0.017
# 3 2021-05-15 12:00:00     보통  41.0      보통   27.0   보통  0.037      좋음  0.020
# 4 2021-05-15 11:00:00     보통  51.0      보통   34.0   보통  0.033      좋음  0.023
#
#   일산화탄소등급  일산화탄소 아황산가스등급  아황산가스   dayName
# 0      좋음    0.4      좋음  0.003  Saturday
# 1      좋음    0.3      좋음  0.003  Saturday
# 2      좋음    0.4      좋음  0.004  Saturday
# 3      좋음    0.4      좋음  0.004  Saturday
# 4      좋음    0.4      좋음  0.005  Saturday

# %%
df['(년-월-일:시)'].dt.hour
# Out:
# 0       15
# 1       14
# 2       13
# 3       12
# 4       11
#         ..
# 1234     5
# 1235     4
# 1236     3
# 1237     2
# 1238     1
# Name: (년-월-일:시), Length: 1239, dtype: int64

# %%
df.groupby(df['(년-월-일:시)'].dt.hour)['PM10'].mean().iloc[[10,22]]
# Out:
# (년-월-일:시)
# 10    70.384615
# 22    69.941176
# Name: PM10, dtype: float64

# %%
Ans = df.groupby(df['(년-월-일:시)'].dt.hour).mean().iloc[[10,22],[0]]
Ans
# Out:
# C:\Users\161332\AppData\Local\Temp\ipykernel_1620\2266762779.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Ans = df.groupby(df['(년-월-일:시)'].dt.hour).mean().iloc[[10,22],[0]]
#                 PM10
# (년-월-일:시)
# 10         70.384615
# 22         69.941176

# %% [markdown]
# ### ✅  81. 날짜 컬럼을 index로 만들어라

# %%
df =pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/seoul_pm.csv')

# %%
df.head()
# Out:
#        (년-월-일:시) PM10등급  PM10 PM2.5등급  PM2.5 오존등급     오존 이산화질소등급  이산화질소  \
# 0  2021-05-15:15     보통  47.0      보통   19.0   좋음  0.017      좋음  0.023
# 1  2021-05-15:14     보통  43.0      보통   20.0   좋음  0.024      좋음  0.019
# 2  2021-05-15:13     보통  34.0      보통   24.0   보통  0.035      좋음  0.017
# 3  2021-05-15:12     보통  41.0      보통   27.0   보통  0.037      좋음  0.020
# 4  2021-05-15:11     보통  51.0      보통   34.0   보통  0.033      좋음  0.023
#
#   일산화탄소등급  일산화탄소 아황산가스등급  아황산가스
# 0      좋음    0.4      좋음  0.003
# 1      좋음    0.3      좋음  0.003
# 2      좋음    0.4      좋음  0.004
# 3      좋음    0.4      좋음  0.004
# 4      좋음    0.4      좋음  0.005

# %%
df = df.set_index('(년-월-일:시)')
df.head()
# Out:
#               PM10등급  PM10 PM2.5등급  PM2.5 오존등급     오존 이산화질소등급  이산화질소 일산화탄소등급  \
# (년-월-일:시)
# 2021-05-15:15     보통  47.0      보통   19.0   좋음  0.017      좋음  0.023      좋음
# 2021-05-15:14     보통  43.0      보통   20.0   좋음  0.024      좋음  0.019      좋음
# 2021-05-15:13     보통  34.0      보통   24.0   보통  0.035      좋음  0.017      좋음
# 2021-05-15:12     보통  41.0      보통   27.0   보통  0.037      좋음  0.020      좋음
# 2021-05-15:11     보통  51.0      보통   34.0   보통  0.033      좋음  0.023      좋음
#
#                일산화탄소 아황산가스등급  아황산가스
# (년-월-일:시)
# 2021-05-15:15    0.4      좋음  0.003
# 2021-05-15:14    0.3      좋음  0.003
# 2021-05-15:13    0.4      좋음  0.004
# 2021-05-15:12    0.4      좋음  0.004
# 2021-05-15:11    0.4      좋음  0.005

# %% [markdown]
# ### ✅  82. 데이터를 주단위로 뽑아서 최소,최대 평균, 표준표차를 구하여라

# %%
df.index
# Out:
# Index(['2021-05-15:15', '2021-05-15:14', '2021-05-15:13', '2021-05-15:12',
#        '2021-05-15:11', '2021-05-15:10', '2021-05-15:09', '2021-05-15:08',
#        '2021-05-15:07', '2021-05-15:06',
#        ...
#        '2021-03-25:10', '2021-03-25:09', '2021-03-25:08', '2021-03-25:07',
#        '2021-03-25:06', '2021-03-25:05', '2021-03-25:04', '2021-03-25:03',
#        '2021-03-25:02', '2021-03-25:01'],
#       dtype='object', name='(년-월-일:시)', length=1239)

# %%
df.index = pd.to_datetime(df.index, format='%Y-%m-%d:%H', errors='coerce')

df
# Out:
#                     PM10등급  PM10 PM2.5등급  PM2.5 오존등급     오존 이산화질소등급  이산화질소  \
# (년-월-일:시)
# 2021-05-15 15:00:00     보통  47.0      보통   19.0   좋음  0.017      좋음  0.023
# 2021-05-15 14:00:00     보통  43.0      보통   20.0   좋음  0.024      좋음  0.019
# 2021-05-15 13:00:00     보통  34.0      보통   24.0   보통  0.035      좋음  0.017
# 2021-05-15 12:00:00     보통  41.0      보통   27.0   보통  0.037      좋음  0.020
# 2021-05-15 11:00:00     보통  51.0      보통   34.0   보통  0.033      좋음  0.023
# ...                    ...   ...     ...    ...  ...    ...     ...    ...
# 2021-03-25 05:00:00     보통  39.0      보통   18.0   좋음  0.026      좋음  0.025
# 2021-03-25 04:00:00     보통  34.0      좋음   15.0   좋음  0.017      보통  0.033
# 2021-03-25 03:00:00     보통  35.0      좋음   13.0   좋음  0.029      좋음  0.025
# 2021-03-25 02:00:00     보통  35.0      좋음   13.0   보통  0.031      좋음  0.025
# 2021-03-25 01:00:00     보통  42.0      좋음   13.0   좋음  0.022      보통  0.037
#
#                     일산화탄소등급  일산화탄소 아황산가스등급  아황산가스
# (년-월-일:시)
# 2021-05-15 15:00:00      좋음    0.4      좋음  0.003
# 2021-05-15 14:00:00      좋음    0.3      좋음  0.003
# 2021-05-15 13:00:00      좋음    0.4      좋음  0.004
# 2021-05-15 12:00:00      좋음    0.4      좋음  0.004
# 2021-05-15 11:00:00      좋음    0.4      좋음  0.005
# ...                     ...    ...     ...    ...
# 2021-03-25 05:00:00      좋음    0.4      좋음  0.003
# 2021-03-25 04:00:00      좋음    0.4      좋음  0.002
# 2021-03-25 03:00:00      좋음    0.4      좋음  0.003
# 2021-03-25 02:00:00      좋음    0.3      좋음  0.003
# 2021-03-25 01:00:00      좋음    0.4      좋음  0.003
#
# [1239 rows x 12 columns]

# %%
Ans = df.resample('W').agg(['min','max','mean','std'])
Ans.head()
# Out:
# C:\Users\161332\AppData\Local\Temp\ipykernel_1620\2644786184.py:1: FutureWarning: ['PM10등급', 'PM2.5등급', '오존등급', '이산화질소등급', '일산화탄소등급', '아황산가스등급'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   Ans = df.resample('W').agg(['min','max','mean','std'])
#             PM10                               PM2.5                    \
#              min    max       mean         std   min    max       mean
# (년-월-일:시)
# 2021-03-28   6.0  160.0  72.760870   43.505303   4.0  113.0  44.597826
# 2021-04-04   3.0  598.0  97.440994  130.308952   1.0  120.0  23.132075
# 2021-04-11  17.0  102.0  41.267081   16.480579   7.0   70.0  21.888199
# 2021-04-18   3.0  367.0  48.396226   43.864437   2.0   38.0  17.138365
# 2021-04-25  17.0  126.0  55.180124   26.617637   7.0   61.0  26.434783
#
#                           오존         ...     이산화질소           일산화탄소       \
#                   std    min    max  ...      mean       std   min  max
# (년-월-일:시)                            ...
# 2021-03-28  29.670743  0.002  0.085  ...  0.044022  0.023382   0.3  1.2
# 2021-04-04  22.568072  0.003  0.055  ...  0.027565  0.014590   0.3  0.9
# 2021-04-11  11.612490  0.009  0.070  ...  0.022609  0.009725   0.3  0.7
# 2021-04-18   7.901673  0.002  0.070  ...  0.023289  0.013008   0.3  0.6
# 2021-04-25  13.147140  0.006  0.090  ...  0.028503  0.014503   0.3  0.8
#
#                                 아황산가스
#                 mean       std    min    max      mean       std
# (년-월-일:시)
# 2021-03-28  0.604348  0.220844  0.002  0.006  0.003283  0.000964
# 2021-04-04  0.444099  0.135483  0.002  0.004  0.002727  0.000524
# 2021-04-11  0.389441  0.088461  0.002  0.004  0.002745  0.000573
# 2021-04-18  0.384277  0.082320  0.002  0.004  0.002465  0.000582
# 2021-04-25  0.457143  0.122838  0.001  0.011  0.003640  0.001791
#
# [5 rows x 24 columns]
