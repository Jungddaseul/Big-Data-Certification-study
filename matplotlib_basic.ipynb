# %% [markdown]
# <a href="https://colab.research.google.com/github/Jungddaseul/Big-Data-Certification-study-/blob/main/matplotlib_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 라이브러리 불러오기

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
print(matplotlib.__version__)
# Out:
# 3.7.1

# %% [markdown]
# ## 그래프 그려보기
# - 대부분 Matplotlib 라이브러리에서 그래프를 그리는 것이 pyplot 서브 모듈 아래 있음
# - 보통 약자로 plt
# - 기분 plot() 함수로 그래프를 표시

# %%
# marker = 'o'(점), '-'(선)
# marker 생략가능
plt.plot([1,2,3,4,5], marker='o', linestyle="--") # '-' 선 : 기본값
plt.plot([11,21,31,41,51], "o") # '-' 선 : 기본값
plt.show()

# %%
x = range(0, 50)
y = range(0, 100, 2)

plt.plot(x, y, 'o')
plt.show()

# %% [markdown]
# ### Matplotlib Markers
# - marker 인자 키워드를 사용하여 특별한 점을 강조

# %%
from matplotlib._api.deprecation import make_keyword_only
import numpy as np

ypoints = np.array([3, 3, 1, 20, 10, 30, 20]) # 7개의 y 값 지정

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
plt.plot(ypoints, marker = '*')
plt.show()

# %% [markdown]
# Marker Reference
# - (다양한 표현)
# https://www.w3schools.com/python/matplotlib_markers.asp
# (https://www.w3schools.com/python/matplotlib_markers.asp)

# %% [markdown]
# ### y = x * x의 그래프 그려보기

# %%
x = range(0, 30)
y = [v * v for v in x]
print(x)
print(y)

plt.plot(x, y, 'ro') # r:red, o : dot
plt.show()
# Out:
# range(0, 30)
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841]

# %% [markdown]
# ### fmt의 파라미터를 다음과 같이 사용

# %%
y = np.array([3, 8, 1, 10])

# ^:b => triangle_up(삼각형)| Dotted line | blue
plt.plot(y, '^:b')
plt.show()

# %%
y = np.array([3, 3, 1, 20, 10])
plt.plot(y , 'o-', ms=15) # o(marker), -(line) ms마커사이즈
plt.show()

# %% [markdown]
# ### 마커 Edge 색 - marker edge color(mec)

# %%
y = np.array([3, 3, 1, 20, 10])
plt.plot(y , marker = 'o', ms=15, mec = 'r')
plt.show()

# %%
plt.plot(y , marker = 'o', ms=15, mfc = 'r')
plt.show()

# %%
# 색상을 지정할 수 있음
plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')

# %%
### 선 굵기
y = np.array([3, 8, 1, 12, 5])
plt.plot(y, linewidth = '12.5')

# %% [markdown]
# ## 여러 개의 그래프 그리기
# 한 화면에 여러개의 그래프를 그리기 위해서는
#
# (1) figure 함수를 통해 Figure 객체를 만든다
#
# (2) add_subplot 메서드를 통해 그리려는 그래프 개수만큼 subplot를 만들면 된다.

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

x1 = np.array([0, 1, 2, 3])
y1 = np.array([13, 18, 11, 10])

x2 = np.array([0, 1, 2, 3])
y2 = np.array([32, 81, 11, 11])

ax1.plot(x1, y1)
ax2.plot(x2, y2)
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(1,3,1) # 1행 3열 중에 첫번째
ax2 = fig.add_subplot(1,3,2) # 1행 3열 중에 두번째
ax3 = fig.add_subplot(1,3,3) # 1행 3열 중에 세번째
plt.show()

# %%
### [추가 실습 3-3A] 3행 1열의 그래프 그리기
x = range(0, 15)
y = [v*v for v in x]

fig, axs = plt.subplots(3, 2, figsize=(10, 10))
axs[0, 0].plot(x, y, 'o')
axs[1, 0].plot(x, y, '-')
axs[2, 0].bar(x, y)
# Out:
# <BarContainer object of 15 artists>

# %%
### [추가 실습 3-3A] 3행 1열의 그래프 그리기
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0.0, 2 * np.pi, 0.1)
sin_y = np.sin(x)
cos_y = np.cos(x)

plt.figure(figsize=(10,12))
fig, axs = plt.subplots(3)
axs[0].plot(x, sin_y, 'b--')
axs[1].plot(x, cos_y, 'r--')
axs[2].plot(x, cos_y, 'r--')
plt.show()

# %% [markdown]
# ### plt.subplots(행, 열) 이용

# %%
### plot, bar 그래프 그리기
x = range(0,15)
y = [v*v for v in x]
fig, axs = plt.subplots(2,2, figsize=(10,10))
axs[0,0].plot(x, y, 'o')
axs[0,1].plot(x, y, '-')
axs[1,0].bar(x, y)
axs[1,1].hist(x, y)
plt.show()

# %% [markdown]
# ### sin, cos 그래프 그려보기

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0.0, 2 * np.pi, 0.1)
sin_y = np.sin(x)
cos_y = np.cos(x)

plt.figure(figsize=(10, 12))
fig, axs = plt.subplots(2)
axs[0].plot(x, sin_y, 'b--')
axs[1].plot(x, cos_y, 'r--')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

x = np.linspace(0, 14, 100)
y1 = np.sin(x)
y2 = 2 * np.sin(x + 0.5)
y3 = 4 * np.sin(x + 1.0)

plt.figure(figsize=(10,6))
plt.plot(x, y1)

# %% [markdown]
# (실습2)
#
# 2행 2열의 그래프를 그려보자.
#
# 1행 1열: sin() 그래프
#
# 1행 2열: cos() 그래프 (표시 형식:빨간색 사각형)
#
# 2행 1열: tan() 그래프 (표시 형식:청록색 점)
#
# 2행 2열: arctan() 그래프 (표시 형식:노란색 원)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0.0, 2 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)
y_tan = np.tan(x)
y_arctan = np.arctan(x)

fig, axs = plt.subplots(2,2, figsize=(10,10))
axs[0,0].plot(x, y_sin)
axs[0,1].plot(x, y_cos, 'rs')
axs[1,0].plot(x, y_tan, 'c.')
axs[1,1].plot(x, y_arctan, 'yo')
plt.show()
